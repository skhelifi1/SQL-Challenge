# %%
import pandas as pd
import psycopg2

from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/employees_db')
connection = engine.connect()

# %%
#Create a histogram to visualize the most common salary ranges for employees.

Salaries=pd.read_sql("SELECT * FROM salaries",connection)
Salaries.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
emp_count= Salaries["emp_no"].nunique()
# print (emp_count)
plt.hist(Salaries['salary'])
plt.xlabel('salary')
plt.ylabel('emp_count')
plt.show()

# %%
#Create a bar chart of average salary by title.
employees=pd.read_sql("SELECT * FROM employees",connection)
employees.head()
# Out:
#    emp_no emp_title  birth_date  first_name  last_name sex   hire_date
# 0  473302     s0001   7/25/1953    Hideyuki   Zallocco   M  1990-04-28
# 1  475053     e0002  11/18/1954       Byong  Delgrande   F  1991-09-07
# 2   57444     e0002   1/30/1958       Berry       Babb   F  1992-03-21
# 3  421786     s0001   9/28/1957       Xiong   Verhoeff   M  1987-11-26
# 4  282238     e0003  10/28/1952  Abdelkader    Baumann   F  1991-01-18

# %%
titles=pd.read_sql("SELECT * FROM titles",connection)
new_titles=titles.rename(columns={"title_id": "emp_title"})
new_titles.head()
# Out:
#   emp_title               title
# 0     s0001               Staff
# 1     s0002        Senior Staff
# 2     e0001  Assistant Engineer
# 3     e0002            Engineer
# 4     e0003     Senior Engineer

# %%
employees_salaries=pd.merge(employees, Salaries, on="emp_no", how="inner")
employees_salaries.head()
# Out:
#    emp_no emp_title  birth_date  first_name  last_name sex   hire_date  salary
# 0  473302     s0001   7/25/1953    Hideyuki   Zallocco   M  1990-04-28   40000
# 1  475053     e0002  11/18/1954       Byong  Delgrande   F  1991-09-07   53422
# 2   57444     e0002   1/30/1958       Berry       Babb   F  1992-03-21   48973
# 3  421786     s0001   9/28/1957       Xiong   Verhoeff   M  1987-11-26   40000
# 4  282238     e0003  10/28/1952  Abdelkader    Baumann   F  1991-01-18   40000

# %%
employees_salaries_titles=pd.merge(employees_salaries, new_titles, on="emp_title", how="inner")
employees_salaries_titles.head()
# Out:
#    emp_no emp_title birth_date  first_name   last_name sex   hire_date  \
# 0  473302     s0001  7/25/1953    Hideyuki    Zallocco   M  1990-04-28
# 1  421786     s0001  9/28/1957       Xiong    Verhoeff   M  1987-11-26
# 2  273487     s0001  4/14/1957   Christoph     Parfitt   M  1991-06-28
# 3  246449     s0001  3/23/1958       Subbu  Bultermann   F  1988-03-25
# 4   48085     s0001  1/19/1964  Venkatesan        Gilg   M  1993-06-28
#
#    salary  title
# 0   40000  Staff
# 1   40000  Staff
# 2   56087  Staff
# 3   87084  Staff
# 4   63016  Staff

# %%
clean_data=employees_salaries_titles.drop(["birth_date", "first_name", "last_name", "sex", "hire_date"], axis=1)

# %%
emp_title=clean_data.groupby("title")
emp_title.head()
# Out:
#         emp_no emp_title  salary               title
# 0       473302     s0001   40000               Staff
# 1       421786     s0001   40000               Staff
# 2       273487     s0001   56087               Staff
# 3       246449     s0001   87084               Staff
# 4        48085     s0001   63016               Staff
# 107384  475053     e0002   53422            Engineer
# 107385   57444     e0002   48973            Engineer
# 107386  477657     e0002   54816            Engineer
# 107387   29920     e0002   40000            Engineer
# 107388   21529     e0002   40000            Engineer
# 154687  282238     e0003   40000     Senior Engineer
# 154688  263976     e0003   40000     Senior Engineer
# 154689  208153     e0003   50183     Senior Engineer
# 154690   13616     e0003   40000     Senior Engineer
# 154691   71530     e0003   69148     Senior Engineer
# 252434  461591     s0002   40000        Senior Staff
# 252435  219881     s0002   40000        Senior Staff
# 252436  205246     s0002   80252        Senior Staff
# 252437  105597     s0002   43841        Senior Staff
# 252438   85093     s0002   97816        Senior Staff
# 279017   17934     e0004   48795    Technique Leader
# 279018  240129     e0004   43548    Technique Leader
# 279019   35270     e0004   40338    Technique Leader
# 279020  402202     e0004   41006    Technique Leader
# 279021  419277     e0004   46833    Technique Leader
# 294165  252000     e0001   40000  Assistant Engineer
# 294166  109820     e0001   40000  Assistant Engineer
# 294167  268613     e0001   53960  Assistant Engineer
# 294168  441330     e0001   54270  Assistant Engineer
# 294169   14193     e0001   62604  Assistant Engineer
# 300000  111877     m0001   53846             Manager
# 300001  111534     m0001   48077             Manager
# 300002  110765     m0001   40055             Manager
# 300003  110420     m0001   40000             Manager
# 300004  110725     m0001   61357             Manager

# %%
avg_salaries=emp_title["salary"].mean()
print(avg_salaries)
# Out:
# title
# Assistant Engineer    48564.434447
# Engineer              48535.336511
# Manager               51531.041667
# Senior Engineer       48506.799871
# Senior Staff          58550.172704
# Staff                 58465.382850
# Technique Leader      48582.896092
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots()
avg_salaries.plot.bar()
ax.set_xlabel("Employee Titles")
ax.set_ylabel("Avg Salarie")
ax.set_title("Avg Salaries per Employee Title")
fig.tight_layout()
plt.show()
